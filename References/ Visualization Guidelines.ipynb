# %% [markdown]
# # 📊 Visualization Guidelines
#
# ## **1️⃣ Purpose of Visualization**
# - Data visualization helps in **understanding patterns, relationships, and trends** within the dataset.
# - It provides **insights** that can guide feature selection and model building.
# - Different visualization techniques are used for **categorical and numerical data analysis**.
#
# ---
#
# ## **2️⃣ Tools & Libraries Used**
# - **Matplotlib**: For creating basic plots and graphs.
# - **Seaborn**: For advanced statistical visualizations.
# - **Pylab**: For integrating Matplotlib with interactive visualizations.
#
# ---
#
# # 📌 **PLOTS USED**
# ## **1️⃣ Violin Plot**
# - **Purpose**:
#   - Shows the **distribution of quantitative data** across categorical variables.
#   - Helps compare distributions between different categories.
#
# ---
#
# ## **2️⃣ Count Plot**
# - **Purpose**:
#   - Displays the **count of observations** in each categorical bin using bars.
#   - Helps understand the distribution of categorical variables.
#
# ---
#
# # 📌 **DEPARTMENT-WISE PERFORMANCE ANALYSIS**
# ## **1️⃣ Sales Department**
# - The **majority of employees** have a **performance rating of Level 3**.
# - **Male employees** have slightly **higher performance ratings** compared to females.
#
# ## **2️⃣ Human Resources**
# - **Most employees fall under Level 3 performance**.
# - **Older employees** tend to have **lower performance** in this department.
# - **Female employees** in HR are performing exceptionally well.
#
# ## **3️⃣ Development Department**
# - **Most employees** are **Level 3 performers**.
# - Employees across **all age groups** tend to perform at **Level 3**.
# - **No significant difference** in performance between **male and female employees**.
#
# ## **4️⃣ Data Science Department**
# - The **highest average performance** (Level 3) is in the **Data Science department**.
# - **Fewer employees** have a **Level 2 performance rating** compared to other departments.
# - The **overall performance** in this department is the **highest among all**.
# - **Male employees** are performing **slightly better** in this department.
#
# ## **5️⃣ Research & Development**
# - **Age does not significantly impact performance levels** in R&D.
# - Employees from **different age groups** are present at **all performance levels**.
# - **Female employees in R&D have strong performance ratings**.
#
# ## **6️⃣ Finance Department**
# - **Performance decreases as age increases** in the Finance department.
# - **Male employees** tend to have **better performance ratings** than females.
# - **Experience is inversely related to performance level** (more experience, lower performance).
#
# ---
#
# ### ✅ **Summary**
# ✔ **Violin Plots** were used to analyze distribution across performance levels.
# ✔ **Count Plots** helped in understanding categorical distributions.
# ✔ Performance varies across departments, with **Data Science** showing the highest ratings.
# ✔ **Age and experience affect performance differently** in each department.
